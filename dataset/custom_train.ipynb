# %%
import os

print(os.path.exists("F:/Omar 3amora/حنكشة projects/TrafficGuard_ComputerVision_ETE_Proj/dataset/valid/images"))
# Out:
# True

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="data.yaml",
    epochs=25,
    patience=5,
    imgsz=640,
    batch=16,
    device=0
    
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.33 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.19  Python-3.10.8 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=25, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=F:\Omar 3amora\ projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\runs\detect\train5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# WARNING ClearML installed but not initialized correctly, not logging this run. It seems ClearML is not configured on this machine!
# To get started with ClearML, setup your own 'clearml-server' or create a free account at https://app.clear.ml
# Setup instructions can be found here: https://clear.ml/docs
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 9.512.8 ms, read: 2.20.8 MB/s, size: 59.8 KB)
# train: Scanning F:\Omar 3amora\حنكشة projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\train\labels.cache... 2099 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2099/2099  0.0s
# val: Fast image access  (ping: 185.4190.9 ms, read: 0.60.6 MB/s, size: 123.2 KB)
# val: Scanning F:\Omar 3amora\حنكشة projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\valid\labels.cache... 900 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 900/900  0.0s
# val: F:\Omar 3amora\ projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\valid\images\car55.jpg: corrupt JPEG restored and saved
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to F:\Omar 3amora\ projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\runs\detect\train5\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to F:\Omar 3amora\ projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\runs\detect\train5
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      2.03G     0.6314      2.158      1.151         15        640: 100% ━━━━━━━━━━━━ 132/132 1.1s/it 2:290.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 1.8it/s 15.7s0.3s
#                    all        900       1150      0.741      0.762      0.825      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      1.92G     0.6825       1.41       1.16          8        640: 100% ━━━━━━━━━━━━ 132/132 3.0it/s 44.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 4.2it/s 7.0s0.2s
#                    all        900       1150      0.699      0.655      0.743      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      1.93G     0.6824       1.25      1.157         10        640: 100% ━━━━━━━━━━━━ 132/132 5.1it/s 25.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.0it/s 5.8s0.2s
#                    all        900       1150      0.729      0.765      0.798      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      1.95G      0.681      1.163      1.154         11        640: 100% ━━━━━━━━━━━━ 132/132 5.1it/s 26.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.0it/s 5.8s0.2s
#                    all        900       1150      0.827      0.649       0.78      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      1.97G     0.6689      1.039      1.151         17        640: 100% ━━━━━━━━━━━━ 132/132 5.0it/s 26.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.2it/s 5.6s0.2s
#                    all        900       1150      0.799      0.821      0.891      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      1.99G     0.6339     0.9439      1.124          8        640: 100% ━━━━━━━━━━━━ 132/132 4.9it/s 26.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.1it/s 5.6s0.2s
#                    all        900       1150      0.895      0.828      0.914      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      1.99G     0.6125     0.8338      1.104          8        640: 100% ━━━━━━━━━━━━ 132/132 4.9it/s 26.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.1it/s 5.6s0.2s
#                    all        900       1150      0.916      0.858      0.929      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      1.99G     0.5902     0.7838      1.093          8        640: 100% ━━━━━━━━━━━━ 132/132 4.9it/s 26.9s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.1it/s 5.7s0.2s
#                    all        900       1150      0.861      0.861      0.931      0.807
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      1.99G     0.5809     0.7423      1.089          9        640: 100% ━━━━━━━━━━━━ 132/132 4.9it/s 26.7s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.1it/s 5.7s0.2s
#                    all        900       1150      0.886      0.856      0.938      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      1.99G     0.5635     0.7176       1.08         14        640: 100% ━━━━━━━━━━━━ 132/132 4.9it/s 27.1s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.1it/s 5.7s0.2s
#                    all        900       1150      0.909      0.876      0.946      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      1.99G     0.5582     0.6791      1.078         11        640: 100% ━━━━━━━━━━━━ 132/132 4.7it/s 27.8s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 4.9it/s 5.9s0.2s
#                    all        900       1150        0.9      0.905      0.957      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25         2G     0.5175     0.6191      1.056          7        640: 100% ━━━━━━━━━━━━ 132/132 4.9it/s 27.2s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.0it/s 5.9s0.2s
#                    all        900       1150      0.957      0.906      0.966       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      1.94G     0.5223     0.6317       1.05          4        640: 100% ━━━━━━━━━━━━ 132/132 4.9it/s 27.0s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.2it/s 5.6s0.2s
#                    all        900       1150      0.931      0.911      0.966      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      1.94G     0.5097     0.5958      1.047         10        640: 100% ━━━━━━━━━━━━ 132/132 4.8it/s 27.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.3it/s 5.5s0.2s
#                    all        900       1150      0.954      0.901      0.961      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      1.95G     0.4894     0.5605      1.038          9        640: 100% ━━━━━━━━━━━━ 132/132 4.8it/s 27.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 29/29 5.2it/s 5.6s0.2s
#                    all        900       1150      0.945      0.933       0.97       0.87
# Closing dataloader mosaic

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train5/weights/best.pt")

results = model.predict(
    source="2.jpg",   # image path
    conf=0.25,
    save=True
)
# Out:
# image 1/1 f:\Omar 3amora\ projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\2.jpg: 480x640 1 van, 78.2ms
# Speed: 2.4ms preprocess, 78.2ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to F:\Omar 3amora\ projects\TrafficGuard_ComputerVision_ETE_Proj\dataset\vehicle dataset\runs\detect\predict
